# %%
import pandas as pd

# %% [markdown]
# Available stations in Madrid:
# https://rp5.ru/docs/search/en

# %% [markdown]
# From Ciudad universitary station:
#   40° 26.76' N lat., 03° 43.8' W
#
#   https://rp5.ru/Weather_archive_in_Madrid,_University_City

# %%
coords = (40.448726, -3.733891) # hardcoded from aprox location on google maps

# %%
df = pd.read_excel('../data/meteo/8220.08.01.2019.14.01.2019.1.0.0.en.utf8.00000000.xls', header=6)
df = pd.read_excel('../data/meteo/8220.01.01.2018.02.05.2019.1.0.0.en.utf8.00000000.xls', header=6)

# %%
df
# Out:
#      Local time in Madrid / University City     T  Po   P  Pa   U  \
# 0                          02.05.2019 10:00  17.8 NaN NaN NaN  52
# 1                          02.05.2019 09:00  15.8 NaN NaN NaN  57
# 2                          02.05.2019 08:00  13.4 NaN NaN NaN  62
# 3                          02.05.2019 07:00  12.7 NaN NaN NaN  61
# 4                          02.05.2019 04:00  13.7 NaN NaN NaN  58
# 5                          02.05.2019 03:00  15.5 NaN NaN NaN  52
# 6                          02.05.2019 02:00  16.0 NaN NaN NaN  48
# 7                          02.05.2019 01:00  17.1 NaN NaN NaN  44
# 8                          02.05.2019 00:00  18.1 NaN NaN NaN  41
# 9                          01.05.2019 22:00  18.4 NaN NaN NaN  37
# 10                         01.05.2019 21:00  19.4 NaN NaN NaN  34
# 11                         01.05.2019 20:00  21.0 NaN NaN NaN  32
# 12                         01.05.2019 19:00  22.4 NaN NaN NaN  31
# ...

# %%
df['station_name'] = df.columns[0]

# %%
df = df.rename(columns={ df.columns[0]: "date" })
df['date'] = pd.to_datetime(df['date'], dayfirst=True)

# %%
df['lat'] = coords[0]
df['lon'] = coords[1]

# %%
df.set_index('date', inplace = True)

# %%
df
# Out:
#                         T  Po   P  Pa   U  \
# date
# 2019-05-02 10:00:00  17.8 NaN NaN NaN  52
# 2019-05-02 09:00:00  15.8 NaN NaN NaN  57
# 2019-05-02 08:00:00  13.4 NaN NaN NaN  62
# 2019-05-02 07:00:00  12.7 NaN NaN NaN  61
# 2019-05-02 04:00:00  13.7 NaN NaN NaN  58
# 2019-05-02 03:00:00  15.5 NaN NaN NaN  52
# 2019-05-02 02:00:00  16.0 NaN NaN NaN  48
# 2019-05-02 01:00:00  17.1 NaN NaN NaN  44
# 2019-05-02 00:00:00  18.1 NaN NaN NaN  41
# 2019-05-01 22:00:00  18.4 NaN NaN NaN  37
# 2019-05-01 21:00:00  19.4 NaN NaN NaN  34
# 2019-05-01 20:00:00  21.0 NaN NaN NaN  32
# 2019-05-01 19:00:00  22.4 NaN NaN NaN  31
# 2019-05-01 18:00:00  22.9 NaN NaN NaN  30
# 2019-05-01 16:00:00  25.1 NaN NaN NaN  29
# 2019-05-01 15:00:00  25.0 NaN NaN NaN  28
# 2019-05-01 14:00:00  23.3 NaN NaN NaN  32
# 2019-05-01 13:00:00  22.5 NaN NaN NaN  33
# 2019-05-01 12:00:00  20.9 NaN NaN NaN  36
# 2019-05-01 10:00:00  16.9 NaN NaN NaN  40
# 2019-05-01 09:00:00  15.0 NaN NaN NaN  43
# ...

# %%
df.to_csv('../data/result/meteo_result.csv')
