# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('../data/result/joined_result.csv')

# %%
df
# Out:
#                     date      Y      S_id     S_lon      S_lat  S_elevation  \
# 0    2019-01-08 00:00:00   78.0  28079024 -3.747347  40.419356          642
# 1    2019-01-08 01:00:00   76.0  28079024 -3.747347  40.419356          642
# 2    2019-01-08 02:00:00   74.0  28079024 -3.747347  40.419356          642
# 3    2019-01-08 03:00:00   62.0  28079024 -3.747347  40.419356          642
# 4    2019-01-08 04:00:00   47.0  28079024 -3.747347  40.419356          642
# 5    2019-01-08 05:00:00   42.0  28079024 -3.747347  40.419356          642
# 6    2019-01-08 06:00:00   37.0  28079024 -3.747347  40.419356          642
# 7    2019-01-08 07:00:00   34.0  28079024 -3.747347  40.419356          642
# 8    2019-01-08 08:00:00   37.0  28079024 -3.747347  40.419356          642
# 9    2019-01-08 09:00:00   41.0  28079024 -3.747347  40.419356          642
# 10   2019-01-08 10:00:00   40.0  28079024 -3.747347  40.419356          642
# ...
